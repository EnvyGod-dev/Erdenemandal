# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
import pkg_resources
import types


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# matplotlib==3.8.3
# numpy==1.26.4
# pandas==1.5.3
# seaborn==0.12.2
# /tmp/ipykernel_26056/3708299036.py:1: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources

# %%
def get_state(data, t, n):
    d = t - n + 1
    block = data[d : t + 1] if d >= 0 else -d * [data[0]] + data[0 : t + 1]
    res = []
    for i in range(n - 1):
        res.append(block[i + 1] - block[i])
    return np.array([res])

# %% [markdown]
# TSLA Time Period: **Mar 23, 2018 - Mar 23, 2019**

# %%
df = pd.read_csv('../dataset/MSFT.csv')
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.061378  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.063570   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.064667   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.063022    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.061926    47894400

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1
l = len(close) - 1

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / np.std(rewards)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(layer_size, 1),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        buy = np.dot(feed, self.weights[2])
        return decision, buy

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, money, max_buy, max_sell):
        self.model = model
        self.initial_money = money
        self.max_buy = max_buy
        self.max_sell = max_sell
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision, buy = self.model.predict(np.array(sequence))
        return np.argmax(decision[0]), int(buy[0])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = get_state(close, 0, window_size + 1)
        inventory = []
        quantity = 0
        for t in range(0, l, skip):
            action, buy = self.act(state)
            next_state = get_state(close, t + 1, window_size + 1)
            if action == 1 and initial_money >= close[t]:
                if buy < 0:
                    buy = 1
                if buy > self.max_buy:
                    buy_units = self.max_buy
                else:
                    buy_units = buy
                total_buy = buy_units * close[t]
                initial_money -= total_buy
                inventory.append(total_buy)
                quantity += buy_units
            elif action == 2 and len(inventory) > 0:
                if quantity > self.max_sell:
                    sell_units = self.max_sell
                else:
                    sell_units = quantity
                quantity -= sell_units
                total_sell = sell_units * close[t]
                initial_money += total_sell

            state = next_state
        return ((initial_money - starting_money) / starting_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = get_state(close, 0, window_size + 1)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        quantity = 0
        for t in range(0, l, skip):
            action, buy = self.act(state)
            next_state = get_state(close, t + 1, window_size + 1)
            if action == 1 and initial_money >= close[t]:
                if buy < 0:
                    buy = 1
                if buy > self.max_buy:
                    buy_units = self.max_buy
                else:
                    buy_units = buy
                total_buy = buy_units * close[t]
                initial_money -= total_buy
                inventory.append(total_buy)
                quantity += buy_units
                states_buy.append(t)
                print(
                    'day %d: buy %d units at price %f, total balance %f'
                    % (t, buy_units, total_buy, initial_money)
                )
            elif action == 2 and len(inventory) > 0:
                bought_price = inventory.pop(0)
                if quantity > self.max_sell:
                    sell_units = self.max_sell
                else:
                    sell_units = quantity
                if sell_units < 1:
                    continue
                quantity -= sell_units
                total_sell = sell_units * close[t]
                initial_money += total_sell
                states_sell.append(t)
                try:
                    invest = ((total_sell - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (t, sell_units, total_sell, invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        print(
            '\ntotal gained %f, total investment %f %%'
            % (initial_money - starting_money, invest)
        )
        plt.figure(figsize = (20, 10))
        plt.plot(close, label = 'true close', c = 'g')
        plt.plot(
            close, 'X', label = 'predict buy', markevery = states_buy, c = 'b'
        )
        plt.plot(
            close, 'o', label = 'predict sell', markevery = states_sell, c = 'r'
        )
        plt.legend()
        plt.show()

# %%
model = Model(window_size, 500, 3)
agent = Agent(model, 10000, 5, 5)
agent.fit(500, 10)
# Out:
# /tmp/ipykernel_26056/857736872.py:22: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return np.argmax(decision[0]), int(buy[0])
# iter 10. reward: 2866.297076
# iter 20. reward: 3326.990074
# iter 30. reward: 4291.248684
# iter 40. reward: 3007.768402
# iter 50. reward: 5033.382555
# iter 60. reward: 5515.582969
# iter 70. reward: 5721.796751
# iter 80. reward: 6007.474210
# iter 90. reward: 5907.273321
# iter 100. reward: 6837.942087
# iter 110. reward: 7067.364310
# iter 120. reward: 7130.023799
# iter 130. reward: 6835.789145
# iter 140. reward: 7307.428259
# iter 150. reward: 6979.250225
# iter 160. reward: 6912.356902
# iter 170. reward: 6979.077604
# iter 180. reward: 6753.218799
# iter 190. reward: 7175.811782
# iter 200. reward: 6154.434218
# iter 210. reward: 7316.090852
# iter 220. reward: 6892.086219
# iter 230. reward: 7369.344170
# iter 240. reward: 7483.831221
# iter 250. reward: 7215.592988
# iter 260. reward: 7356.616420
# iter 270. reward: 5340.717381
# iter 280. reward: 7269.278423
# iter 290. reward: 5264.464155
# iter 300. reward: 7179.686814
# iter 310. reward: 7164.373755
# iter 320. reward: 7075.741429
# iter 330. reward: 7616.358765
# iter 340. reward: 7259.403404
# iter 350. reward: 6743.312895
# iter 360. reward: 6099.894798
# iter 370. reward: 7641.074644
# iter 380. reward: 7401.659527
# iter 390. reward: 7703.038124
# iter 400. reward: 7540.206551
# iter 410. reward: 7509.487713
# iter 420. reward: 7713.585671
# iter 430. reward: 6732.471959
# iter 440. reward: 6648.109806
# iter 450. reward: 7243.435637
# iter 460. reward: 5475.933480
# iter 470. reward: 6042.110862
# iter 480. reward: 7063.321286
# iter 490. reward: 6833.591155
# iter 500. reward: 7037.474411
# time taken to train: 1206.698846578598 seconds

# %%
agent.buy()
# Out:
# /tmp/ipykernel_26056/857736872.py:22: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return np.argmax(decision[0]), int(buy[0])
# day 0: buy 5 units at price 0.486110, total balance 9999.513890
# day 1: buy 5 units at price 0.503470, total balance 9999.010420
# day 2: buy 5 units at price 0.512155, total balance 9998.498265
# day 3: buy 5 units at price 0.499130, total balance 9997.999135
# day 4: buy 5 units at price 0.490450, total balance 9997.508685
# day 5: buy 5 units at price 0.477430, total balance 9997.031255
# day 6: buy 5 units at price 0.464410, total balance 9996.566845
# day 7: buy 5 units at price 0.451390, total balance 9996.115455
# day 8: buy 5 units at price 0.460070, total balance 9995.655385
# day 9: buy 5 units at price 0.473090, total balance 9995.182295
# day 10: buy 5 units at price 0.481770, total balance 9994.700525
# day 11: buy 5 units at price 0.477430, total balance 9994.223095
# day 12: buy 5 units at price 0.473090, total balance 9993.750005
# day 13: buy 5 units at price 0.477430, total balance 9993.272575
# day 14: buy 5 units at price 0.481770, total balance 9992.790805
# day 15: buy 5 units at price 0.481770, total balance 9992.309035
# day 16: buy 5 units at price 0.473090, total balance 9991.835945
# day 17: buy 5 units at price 0.477430, total balance 9991.358515
# day 18: buy 5 units at price 0.486110, total balance 9990.872405
# day 19: buy 5 units at price 0.490450, total balance 9990.381955
# day 20: buy 5 units at price 0.499130, total balance 9989.882825
# day 21: buy 5 units at price 0.503470, total balance 9989.379355
# day 22: buy 5 units at price 0.503470, total balance 9988.875885
# day 23: buy 5 units at price 0.520835, total balance 9988.355050
# day 24: buy 5 units at price 0.525175, total balance 9987.829875
# day 25: buy 5 units at price 0.507815, total balance 9987.322060
# day 700: buy 5 units at price 1.727430, total balance 8978.983478
# day 701: buy 5 units at price 1.762155, total balance 8977.221323
# day 702: buy 5 units at price 1.779515, total balance 8975.441808
# day 703: buy 5 units at price 1.814235, total balance 8973.627573
# day 704: buy 5 units at price 1.805555, total balance 8971.822018
# day 705: buy 5 units at price 1.805555, total balance 8970.016463
# day 706: buy 5 units at price 1.796875, total balance 8968.219588
# day 707: buy 5 units at price 1.814235, total balance 8966.405353
# day 708: buy 5 units at price 1.848960, total balance 8964.556393
# day 709: buy 5 units at price 1.848960, total balance 8962.707433
# day 710: buy 5 units at price 1.861980, total balance 8960.845453
# day 711: buy 5 units at price 1.883680, total balance 8958.961773
# day 712: buy 5 units at price 1.853300, total balance 8957.108473
# day 713: buy 5 units at price 1.840280, total balance 8955.268193
# day 714: buy 5 units at price 1.822915, total balance 8953.445278
# day 715: buy 5 units at price 1.805555, total balance 8951.639723
# day 716: buy 5 units at price 1.822915, total balance 8949.816808
# day 717: buy 5 units at price 1.822915, total balance 8947.993893
# day 718: buy 5 units at price 1.840280, total balance 8946.153613
# day 719: buy 5 units at price 1.844620, total balance 8944.308993
# day 720: buy 5 units at price 1.788195, total balance 8942.520798
# day 721: buy 5 units at price 1.788195, total balance 8940.732603
# day 722: buy 5 units at price 1.857640, total balance 8938.874963
# day 723: buy 5 units at price 1.879340, total balance 8936.995623
# ...
# day 8797, sell 5 units at price 1210.999985, investment 798.701254 %, total balance 530428.541487,
# day 8799, sell 5 units at price 1218.850020, investment 4431.040967 %, total balance 531647.391507,
# day 8800, sell 5 units at price 1214.100035, investment 807.399129 %, total balance 532861.491542,
# day 8801, sell 5 units at price 1222.450025, investment 815.007538 %, total balance 534083.941567,
# day 8802, sell 5 units at price 1224.950025, investment 816.192988 %, total balance 535308.891592,
# day 8803, sell 5 units at price 1218.499985, investment 810.007423 %, total balance 536527.391577,
# day 8804, sell 5 units at price 1220.999985, investment 812.897185 %, total balance 537748.391562,
# day 8805, sell 5 units at price 1218.949965, investment 814.098211 %, total balance 538967.341527,
# day 8806, sell 5 units at price 1204.850005, investment 799.141828 %, total balance 540172.191532,
# day 8807, sell 5 units at price 1172.549975, investment 996.661032 %, total balance 541344.741507,
# day 8809, sell 5 units at price 1172.750015, investment 4279.200789 %, total balance 542517.491522,
# day 8811, sell 5 units at price 1161.900025, investment 784.583194 %, total balance 543679.391547,
# day 8812, sell 5 units at price 1184.700010, investment 4435.604765 %, total balance 544864.091557,
# day 8813, sell 5 units at price 1169.349975, investment 788.563811 %, total balance 546033.441532,
# day 8814, sell 5 units at price 1137.799990, investment 775.904534 %, total balance 547171.241522,
# day 8815, sell 5 units at price 1133.649980, investment 776.759425 %, total balance 548304.891502,
# day 8818, sell 5 units at price 1168.899995, investment 811.422998 %, total balance 549473.791497,
# day 8819: buy 1 units at price 232.419998, total balance 549241.371499
# day 8820, sell 5 units at price 1185.650025, investment 823.763167 %, total balance 550427.021524,
# day 8822, sell 5 units at price 1174.049990, investment 4412.106034 %, total balance 551601.071514,
# day 8825: buy 1 units at price 230.720001, total balance 551370.351513
# day 8826: buy 5 units at price 1151.750030, total balance 550218.601483
# day 8829: buy 5 units at price 1177.300035, total balance 549041.301448
# day 8832: buy 1 units at price 235.240005, total balance 548806.061443
# day 8833: buy 5 units at price 1159.250030, total balance 547646.811413
# day 8834, sell 5 units at price 1178.850020, investment 806.459070 %, total balance 548825.661433,
# day 8836, sell 5 units at price 1245.350035, investment 853.925689 %, total balance 550071.011468,
# day 8837, sell 5 units at price 1239.300005, investment 4633.766253 %, total balance 551310.311473,
# day 8838, sell 5 units at price 1249.499970, investment 850.913183 %, total balance 552559.811443,
# day 8840, sell 5 units at price 1279.250030, investment 4747.480403 %, total balance 553839.061473,
# day 8841, sell 5 units at price 1279.550020, investment 867.158026 %, total balance 555118.611493,
# day 8842, sell 5 units at price 1292.449950, investment 887.356723 %, total balance 556411.061443,
# day 8843, sell 5 units at price 1277.949980, investment 4755.433055 %, total balance 557689.011423,
# day 8844, sell 5 units at price 1297.500000, investment 891.972477 %, total balance 558986.511423,
# day 8845, sell 5 units at price 1303.699950, investment 893.673742 %, total balance 560290.211373,
# day 8847, sell 5 units at price 1291.300050, investment 890.640621 %, total balance 561581.511423,
# day 8848, sell 5 units at price 1302.899935, investment 899.923243 %, total balance 562884.411358,
# day 8849, sell 5 units at price 1285.850065, investment 890.258078 %, total balance 564170.261423,
# day 8850, sell 5 units at price 1305.749970, investment 4920.184429 %, total balance 565476.011393,
# day 8851, sell 5 units at price 1307.749940, investment 908.677162 %, total balance 566783.761333,
# day 8852, sell 5 units at price 1309.850005, investment 0.000000 %, total balance 568093.611338,
# day 8853, sell 5 units at price 1272.799990, investment 892.436639 %, total balance 569366.411328,
# day 8854, sell 5 units at price 1262.549975, investment 4855.062696 %, total balance 570628.961303,
# day 8856, sell 5 units at price 1259.300005, investment 4891.280242 %, total balance 571888.261308,
# day 8857, sell 5 units at price 1238.949965, investment 883.293584 %, total balance 573127.211273,
# day 8858, sell 5 units at price 1232.350005, investment 871.501739 %, total balance 574359.561278,
# day 8859, sell 5 units at price 1248.649980, investment 889.029687 %, total balance 575608.211258,
# day 8860, sell 5 units at price 1262.300035, investment 4917.090759 %, total balance 576870.511293,
# day 8861, sell 5 units at price 1235.899965, investment 4788.844605 %, total balance 578106.411258,
# day 8862, sell 5 units at price 1231.149980, investment 874.782249 %, total balance 579337.561238,
# day 8864, sell 5 units at price 1215.149995, investment 865.554227 %, total balance 580552.711233,
# day 8866, sell 5 units at price 1225.899965, investment 874.096118 %, total balance 581778.611198,
# day 8867, sell 5 units at price 1215.400010, investment 854.377745 %, total balance 582994.011208,
# day 8868, sell 5 units at price 1215.599975, investment 857.165335 %, total balance 584209.611183,
# day 8869: buy 5 units at price 1232.399980, total balance 582977.211203
# day 8872: buy 5 units at price 1258.600005, total balance 581718.611198
# day 8873, sell 5 units at price 1257.450025, investment 893.638937 %, total balance 582976.061223,
# day 8874: buy 1 units at price 249.309998, total balance 582726.751225
# day 8875: buy 1 units at price 249.679993, total balance 582477.071232
# day 8876: buy 5 units at price 1236.999970, total balance 581240.071262
# day 8878: buy 1 units at price 245.710007, total balance 580994.361255
# day 8879: buy 1 units at price 250.789993, total balance 580743.571262
# day 8880: buy 5 units at price 1269.049990, total balance 579474.521272
# day 8881: buy 1 units at price 252.570007, total balance 579221.951265
# day 8882: buy 5 units at price 1267.949980, total balance 577954.001285
# day 8885, sell 5 units at price 1299.450075, investment 921.981970 %, total balance 579253.451360,
# day 8886, sell 5 units at price 1291.799925, investment 929.732902 %, total balance 580545.251285,
# day 8887, sell 5 units at price 1286.900025, investment 925.009935 %, total balance 581832.151310,
# day 8888: buy 1 units at price 260.899994, total balance 581571.251316
# day 8889, sell 5 units at price 1297.149965, investment 5107.346307 %, total balance 582868.401281,
# day 8891, sell 5 units at price 1327.550050, investment 977.994400 %, total balance 584195.951331,
# day 8892, sell 5 units at price 1326.349945, investment 980.969756 %, total balance 585522.301276,
# day 8893, sell 5 units at price 1333.450010, investment 997.038309 %, total balance 586855.751286,
# day 8894, sell 5 units at price 1325.099945, investment 995.123876 %, total balance 588180.851231,
# day 8895, sell 5 units at price 1343.600005, investment 1020.133393 %, total balance 589524.451236,
# day 8896, sell 5 units at price 1356.999970, investment 1022.415194 %, total balance 590881.451206,
# day 8897, sell 5 units at price 1354.499970, investment 5478.665215 %, total balance 592235.951176,
# day 8898, sell 5 units at price 1358.000030, investment 1022.314028 %, total balance 593593.951206,
# day 8899, sell 5 units at price 1388.249970, investment 5703.720610 %, total balance 594982.201176,
# day 8900, sell 5 units at price 1388.300020, investment 5646.274917 %, total balance 596370.501196,
# day 8901, sell 5 units at price 1399.649965, investment 1058.171258 %, total balance 597770.151161,
# day 8902, sell 5 units at price 1387.100065, investment 1050.165844 %, total balance 599157.251226,
# day 8903, sell 5 units at price 1389.700010, investment 1047.090392 %, total balance 600546.951236,
# day 8904, sell 5 units at price 1386.600035, investment 1033.306164 %, total balance 601933.551271,
# day 8905, sell 5 units at price 1404.900055, investment 1038.954240 %, total balance 603338.451326,
# day 8906, sell 5 units at price 1412.550050, investment 5527.689442 %, total balance 604751.001376,
# day 8907, sell 5 units at price 1405.149995, investment 1026.824329 %, total balance 606156.151371,
# day 8908, sell 5 units at price 1403.750000, investment 5521.746320 %, total balance 607559.901371,
# day 8909, sell 5 units at price 1385.050050, investment 5370.181872 %, total balance 608944.951421,
# day 8910, sell 5 units at price 1396.600035, investment 5477.475955 %, total balance 610341.551456,
# day 8911, sell 5 units at price 1406.999970, investment 1032.850217 %, total balance 611748.551426,
# day 8912, sell 5 units at price 1430.700075, investment 1069.828400 %, total balance 613179.251501,
# day 8913, sell 5 units at price 1448.350065, investment 5775.659493 %, total balance 614627.601566,
# day 8914, sell 5 units at price 1445.249940, investment 1073.568817 %, total balance 616072.851506,
# day 8915, sell 5 units at price 1432.700045, investment 5567.325903 %, total balance 617505.551551,
# day 8916, sell 5 units at price 1431.100005, investment 5628.983207 %, total balance 618936.651556,
# day 8917, sell 5 units at price 1432.500000, investment 5685.541195 %, total balance 620369.151556,
# day 8919, sell 5 units at price 1424.100035, investment 5598.679612 %, total balance 621793.251591,
# day 8920, sell 5 units at price 1435.599975, investment 1038.010285 %, total balance 623228.851566,
# day 8921, sell 5 units at price 1432.550050, investment 5577.962941 %, total balance 624661.401616,
# day 8922, sell 5 units at price 1447.599945, investment 1047.977797 %, total balance 626109.001561,
# day 8923, sell 5 units at price 1447.299955, investment 1062.489924 %, total balance 627556.301516,
# day 8924, sell 5 units at price 1441.649935, investment 1785.249032 %, total balance 628997.951451,
# day 8926, sell 5 units at price 1434.750060, investment 5435.301157 %, total balance 630432.701511,
# day 8927, sell 5 units at price 1449.049990, investment 5527.378602 %, total balance 631881.751501,
# day 8928, sell 5 units at price 1464.250030, investment 1023.321849 %, total balance 633346.001531,
# day 8929, sell 5 units at price 1473.000030, investment 5607.090612 %, total balance 634819.001561,
# day 8930, sell 5 units at price 1465.399935, investment 5662.484998 %, total balance 636284.401496,
# day 8932, sell 5 units at price 1483.849945, investment 5762.702503 %, total balance 637768.251441,
# day 8933, sell 5 units at price 1521.799925, investment 1100.157622 %, total balance 639290.051366,
# day 8934, sell 5 units at price 1523.249970, investment 1106.056983 %, total balance 640813.301336,
# day 8935, sell 5 units at price 1513.099975, investment 5942.731288 %, total balance 642326.401311,
# day 8936, sell 5 units at price 1510.050050, investment 1106.110215 %, total balance 643836.451361,
# day 8937, sell 5 units at price 1495.449980, investment 1089.224636 %, total balance 645331.901341,
# day 8939, sell 5 units at price 1517.949980, investment 5962.100317 %, total balance 646849.851321,
# day 8940, sell 5 units at price 1509.400025, investment 1105.109849 %, total balance 648359.251346,
# day 8941, sell 5 units at price 1509.149935, investment 1103.948891 %, total balance 649868.401281,
# day 8942, sell 5 units at price 1505.749970, investment 5901.394859 %, total balance 651374.151251,
# day 8943, sell 5 units at price 1505.700075, investment 1112.318901 %, total balance 652879.851326,
# day 8944, sell 5 units at price 1500.899965, investment 1114.811838 %, total balance 654380.751291,
# day 8945, sell 5 units at price 1501.049955, investment 1101.801405 %, total balance 655881.801246,
# day 8946, sell 5 units at price 1486.250000, investment 1105.882353 %, total balance 657368.051246,
# day 8948, sell 5 units at price 1484.949950, investment 5818.493224 %, total balance 658853.001196,
# day 8949, sell 5 units at price 1498.950045, investment 5827.046207 %, total balance 660351.951241,
# day 8950, sell 5 units at price 1524.100035, investment 1090.238169 %, total balance 661876.051276,
# day 8951, sell 5 units at price 1526.100005, investment 5847.388952 %, total balance 663402.151281,
# day 8952: buy 1 units at price 299.869995, total balance 663102.281286
# day 8955, sell 5 units at price 1492.899935, investment 1057.735461 %, total balance 664595.181221,
# day 8956, sell 5 units at price 1497.799990, investment 5762.231110 %, total balance 666092.981211,
# day 8957, sell 5 units at price 1496.750030, investment 5621.521521 %, total balance 667589.731241,
# day 8958: buy 1 units at price 294.170013, total balance 667295.561228
# day 8964, sell 5 units at price 1443.800050, investment 1002.558224 %, total balance 668739.361278,
# day 8965: buy 5 units at price 1465.549925, total balance 667273.811353
# day 8966, sell 5 units at price 1474.250030, investment 5640.849026 %, total balance 668748.061383,
# day 8967: buy 1 units at price 294.850006, total balance 668453.211377
# day 8968: buy 1 units at price 294.230011, total balance 668158.981366
# day 8971, sell 5 units at price 1513.750000, investment 1078.474069 %, total balance 669672.731366,
# day 8972, sell 5 units at price 1521.049955, investment 1082.776061 %, total balance 671193.781321,
# day 8973, sell 5 units at price 1536.450045, investment 1093.359258 %, total balance 672730.231366,
# day 8974: buy 1 units at price 308.230011, total balance 672422.001355
# day 8978, sell 5 units at price 1540.650025, investment 1052.318642 %, total balance 673962.651380,
# day 8979: buy 1 units at price 310.109985, total balance 673652.541395
# day 8980, sell 5 units at price 1615.850065, investment 5844.996560 %, total balance 675268.391460,
# day 8982, sell 5 units at price 1658.099975, investment 1119.191113 %, total balance 676926.491435,
# day 8983, sell 5 units at price 1646.849975, investment 1119.888870 %, total balance 678573.341410,
# day 8984, sell 5 units at price 1665.650025, investment 6230.863125 %, total balance 680238.991435,
# day 8986, sell 5 units at price 1682.200010, investment 6303.502132 %, total balance 681921.191445,
# day 8987, sell 5 units at price 1680.299990, investment 1189.067886 %, total balance 683601.491435,
# day 8988, sell 5 units at price 1684.949950, investment 1196.115346 %, total balance 685286.441385,
# day 8989, sell 5 units at price 1679.750060, investment 1200.116146 %, total balance 686966.191445,
# day 8990, sell 5 units at price 1653.999940, investment 1197.763782 %, total balance 688620.191385,
# day 8991, sell 5 units at price 1662.149965, investment 1211.878425 %, total balance 690282.341350,
# day 8992, sell 5 units at price 1683.600005, investment 1232.489121 %, total balance 691965.941355,
# day 8993, sell 5 units at price 1680.350035, investment 1229.916925 %, total balance 693646.291390,
# day 8994, sell 5 units at price 1697.550050, investment 1239.818508 %, total balance 695343.841440,
# day 8995, sell 5 units at price 1695.599975, investment 1221.075166 %, total balance 697039.441415,
# day 8996, sell 5 units at price 1706.349945, investment 1215.612860 %, total balance 698745.791360,
# day 8997, sell 5 units at price 1715.549925, investment 1233.501691 %, total balance 700461.341285,
# day 8998, sell 5 units at price 1699.149935, investment 6563.333078 %, total balance 702160.491220,
# day 9000, sell 5 units at price 1689.550020, investment 1252.722194 %, total balance 703850.041240,
# day 9001, sell 5 units at price 1648.399965, investment 1236.359923 %, total balance 705498.441205,
# day 9002, sell 5 units at price 1683.150025, investment 1268.971147 %, total balance 707181.591230,
# day 9003, sell 5 units at price 1652.949980, investment 1251.553596 %, total balance 708834.541210,
# day 9004, sell 5 units at price 1650.399935, investment 1252.232638 %, total balance 710484.941145,
# day 9005, sell 5 units at price 1647.449950, investment 6679.629703 %, total balance 712132.391095,
# day 9006, sell 5 units at price 1615.050050, investment 6467.913989 %, total balance 713747.441145,
#
# total gained 703747.441145, total investment 7037.474411 %
